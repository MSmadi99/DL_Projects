# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:45e17617-a2cd-462e-97b7-aa8344d1c210.png)

# %% [markdown]
# ![image.png](attachment:6f8e57f3-47a1-4be8-a591-b0af35eab1d6.png)

# %%
def ReLU(x):
    data = [max(0, value) for value in x]
    return np.array(data, dtype=float)

def der_ReLU(x):
    data = [1 if value > 0 else 0 for value in x]
    return np.array(data, dtype=float)

# %%
X_data = np.linspace(-10, 10, 100)
y_data = ReLU(X_data)
dy_data = der_ReLU(X_data)

# %%
plt.plot(X_data, y_data, X_data, dy_data)
plt.title('ReLU Activation Function and Derivative')
plt.legend(['ReLU', 'der_ReLU'])
plt.grid()
plt.show()
