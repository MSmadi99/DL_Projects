# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:5d022154-2b92-44fa-8584-32a6e78940fb.png)

# %% [markdown]
# ![image.png](attachment:92315f74-c17b-49cf-b894-ceba68c158b7.png)

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def der_sigmoid(x):  # derivative of sigmoid
    return sigmoid(x) * (1 - sigmoid(x))

# %%
X_data = np.linspace(-10, 10, 100)
y_data = sigmoid(X_data)
dy_data = der_sigmoid(X_data)

# %%
plt.plot(X_data, y_data, X_data, dy_data)
plt.title('Sigmoid Activation Function & Derivative')
plt.legend(['sigmoid', 'der_sigmoid'])
plt.grid()
plt.show()
